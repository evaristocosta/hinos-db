# %% [markdown]
# # Análise de Embeddings dos Hinos da ICM
# Este notebook explora técnicas de embeddings para representar os textos dos hinos da coletânea principal da Igreja Cristã Maranata.
#
# O objetivo é aplicar modelos de vetorização, calcular similaridade, realizar agrupamentos e extrair tópicos dos louvores, utilizando métodos como FastText, PCA, t-SNE, UMAP, KMeans, LDA e NMF.
#
# ---
# **Conteúdo do notebook:**
# - Carregamento do modelo FastText e dos dados tratados
# - Geração de embeddings com diferentes estratégias de peso
# - Cálculo de similaridade entre hinos
# - Visualização de matrizes de similaridade
# - Redução de dimensionalidade (PCA, t-SNE, UMAP)
# - Agrupamento de hinos por KMeans
# - Extração de tópicos com LDA e NMF
# - Visualização dos agrupamentos e tópicos
# - Salvamento dos resultados para uso futuro
#
# Este material é público e pode ser compartilhado para fins de pesquisa, estudo ou divulgação cultural.

# %% [markdown]
# # Parte 4 - Embeddings

# %% [markdown]
# ---
#
# **A seguir:** Carregamento do modelo FastText pré-treinado para português, utilizado para gerar embeddings das palavras dos hinos.

# %%
import fasttext

# Modelo baixado diretamente do site do fasttext
# (https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.pt.300.bin.gz)
model = fasttext.load_model("../../../shared/models/cc.pt.300.bin")

# Outra alternativa
# fasttext.util.download_model('pt', if_exists='ignore')

# %% [markdown]
# ---
#
# **A seguir:** Carregamento dos dados dos hinos já tokenizados, prontos para análise de embeddings.

# %%
import pandas as pd

hinos_analise: pd.DataFrame = pd.read_pickle(
    "..\\assets\\hinos_analise_tokens_ngrams.pkl"
)

# %% [markdown]
# ---
#
# **A seguir:** Geração dos embeddings dos hinos utilizando diferentes estratégias de peso: TF-IDF, penalização por comprimento e média uniforme.

# %%
import numpy as np
from collections import Counter


def embed_text_weighted(tokens, model, method="tfidf"):
    """Embedding com diferentes estratégias de peso"""
    if not tokens:
        return np.zeros(model.get_dimension())

    vectors = []
    weights = []

    if method == "tfidf":
        # Peso baseado em frequência inversa (palavras raras = mais peso)
        token_counts = Counter(tokens)
        total_docs = len(hinos_analise)  # ou seu corpus total

        for word in tokens:
            vector = model.get_word_vector(word)
            # Simulação simples de TF-IDF
            tf = token_counts[word] / len(tokens)
            idf = np.log(
                total_docs
                / (
                    1
                    + sum(
                        1
                        for doc_tokens in hinos_analise["tokens_no_stops"]
                        if word in doc_tokens
                    )
                )
            )
            weight = tf * idf

            vectors.append(vector)
            weights.append(weight)

    elif method == "uniform":
        # Sua abordagem atual
        vectors = [model.get_word_vector(word) for word in tokens]
        weights = [1.0] * len(vectors)

    elif method == "length_penalty":
        # Penaliza documentos muito longos
        vectors = [model.get_word_vector(word) for word in tokens]
        weights = [1.0 / np.sqrt(len(tokens))] * len(vectors)

    # Média ponderada
    weighted_sum = np.average(vectors, axis=0, weights=weights)
    return weighted_sum


# Teste diferentes abordagens
hinos_analise["word_embedding_tfidf"] = hinos_analise["tokens_no_stops"].apply(
    lambda t: embed_text_weighted(t, model, "tfidf")
)

hinos_analise["word_embedding_length_penalty"] = hinos_analise["tokens_no_stops"].apply(
    lambda t: embed_text_weighted(t, model, "length_penalty")
)

hinos_analise["word_embedding"] = hinos_analise["tokens_no_stops"].apply(
    lambda t: embed_text_weighted(t, model, "uniform")
)
hinos_analise.head()
# Out:
#                                            nome  \
# numero
# 0                   AQUILO QUE FUI NÃO SOU MAIS
# 1                   O SANGUE DE JESUS TEM PODER
# 2       O SANGUE DE JESUS TEM PODER PARA SALVAR
# 3                                    CLAMO A TI
# 4                          QUANDO TE PROSTRARES
#
#                                                     texto  \
# numero
# 0       AQUILO QUE FUI NÃO SOU MAIS,\nNEM SOU TUDO O Q...
# 1       O SANGUE DE JESUS TEM PODER,\nPODER QUE A MIM ...
# 2       O SANGUE DE JESUS TEM PODER (2x)\nO SANGUE DE ...
# 3       CLAMO A TI, Ó MEU SENHOR,\nCLAMO A TI, MEU SAL...
# 4       QUANDO TE PROSTRARES DIANTE DE DEUS,\nLEMBRA Q...
#
#                                          texto_processado  categoria_id  \
# numero
# 0       AQUILO QUE FUI NÃO SOU MAIS,\nNEM SOU TUDO O Q...           7.0
# 1       O SANGUE DE JESUS TEM PODER,\nPODER QUE A MIM ...           1.0
# 2       O SANGUE DE JESUS TEM PODER <bis tipo='2'>\nO ...           1.0
# 3       CLAMO A TI, Ó MEU SENHOR,<bis>\nCLAMO A TI, ME...           1.0
# 4       QUANDO TE PROSTRARES DIANTE DE DEUS,<bis>\nLEM...           1.0
#
#                           categoria     categoria_abr  \
# numero
# 0       VOLTA DE JESUS E ETERNIDADE  VOLTA DE JESU...
# 1                            CLAMOR            CLAMOR
# 2                            CLAMOR            CLAMOR
# 3                            CLAMOR            CLAMOR
# 4                            CLAMOR            CLAMOR
#
#                                               texto_limpo  \
# numero
# 0       AQUILO QUE FUI NÃO SOU MAIS, NEM SOU TUDO O QU...
# 1       O SANGUE DE JESUS TEM PODER, PODER QUE A MIM P...
# 2       O SANGUE DE JESUS TEM PODER O SANGUE DE JESUS,...
# 3       CLAMO A TI, Ó MEU SENHOR, CLAMO A TI, MEU SALV...
# 4       QUANDO TE PROSTRARES DIANTE DE DEUS, LEMBRA QU...
#
#                                                    tokens  \
# numero
# 0       [aquilo, que, fui, não, sou, mais, nem, sou, t...
# 1       [o, sangue, de, jesus, tem, poder, poder, que,...
# 2       [o, sangue, de, jesus, tem, poder, o, sangue, ...
# 3       [clamo, a, ti, ó, meu, senhor, clamo, a, ti, m...
# 4       [quando, te, prostrares, diante, de, deus, lem...
#
#                                           tokens_no_stops  num_tokens  \
# numero
# 0       [tudo, devo, graça, vê, certo, vou, glória, cr...         124
# 1       [sangue, jesus, pode, valer, comunhão, posso, ...         110
# 2       [sangue, jesus, sangue, jesus, sangue, jesus, ...          50
# 3       [clamo, senhor, clamo, salvador, sangue, vida,...          41
# 4       [prostrares, diante, deus, lembra, jesus, pede...          51
#
#                                               texto_unico  num_tokens_unico  \
# numero
# 0       AQUILO QUE FUI NÃO SOU MAIS, NEM SOU TUDO O QU...                45
# 1       O SANGUE DE JESUS TEM PODER, PODER QUE A MIM P...                29
# 2       O SANGUE DE JESUS TEM PODER O SANGUE DE JESUS,...                20
# 3       CLAMO A TI, Ó MEU SENHOR, CLAMO A TI, MEU SALV...                17
# 4       QUANDO TE PROSTRARES DIANTE DE DEUS, LEMBRA QU...                21
#
#                                                   bigrams  \
# numero
# 0       [(tudo, devo), (devo, graça), (graça, vê), (vê...
# 1       [(sangue, jesus), (jesus, pode), (pode, valer)...
# 2       [(sangue, jesus), (jesus, sangue), (sangue, je...
# 3       [(clamo, senhor), (senhor, clamo), (clamo, sal...
# 4       [(prostrares, diante), (diante, deus), (deus, ...
#
#                                                  trigrams  \
# numero
# 0       [(tudo, devo, graça), (devo, graça, vê), (graç...
# 1       [(sangue, jesus, pode), (jesus, pode, valer), ...
# 2       [(sangue, jesus, sangue), (jesus, sangue, jesu...
# 3       [(clamo, senhor, clamo), (senhor, clamo, salva...
# 4       [(prostrares, diante, deus), (diante, deus, le...
#
#                                                tokens_str  \
# numero
# 0       tudo devo graça vê certo vou glória cristo viv...
# 1       sangue jesus pode valer comunhão posso sentir ...
# 2       sangue jesus sangue jesus sangue jesus sangue ...
# 3       clamo senhor clamo salvador sangue vida bendit...
# 4       prostrares diante deus lembra jesus pede auxíl...
#
#                                      word_embedding_tfidf  \
# numero
# 0       [0.00404348330303623, -0.008927922803901167, 0...
# 1       [0.016268169690459036, -0.03780018324862145, 0...
# 2       [0.057070357465712124, -0.029866876979268066, ...
# 3       [-0.017152484745511842, -0.02537855130522809, ...
# 4       [0.014124712794585577, -0.04920271710308455, 0...
#
#                             word_embedding_length_penalty  \
# numero
# 0       [-0.00153114204812381, -0.007698320953123683, ...
# 1       [0.014770387013539166, -0.045391445674387555, ...
# 2       [0.04426600411534309, -0.04770462671294807, -0...
# 3       [-0.010632061598110285, -0.029406396781696993,...
# 4       [0.012466162831212081, -0.043775063362859544, ...
#
#                                            word_embedding
# numero
# 0       [-0.00153114204812381, -0.007698320953123686, ...
# 1       [0.014770387013539159, -0.04539144567438755, 0...
# 2       [0.044266004115343094, -0.04770462671294808, -...
# 3       [-0.010632061598110287, -0.029406396781696993,...
# 4       [0.012466162831212083, -0.043775063362859544, ...

# %% [markdown]
# ---
#
# **A seguir:** Cálculo da similaridade entre hinos usando os embeddings gerados, comparação dos métodos e exibição dos hinos mais semelhantes ao hino de referência.

# %%
from sklearn.metrics.pairwise import cosine_similarity

sims_tfidf = cosine_similarity(list(hinos_analise["word_embedding_tfidf"]))
sims_lp = cosine_similarity(list(hinos_analise["word_embedding_length_penalty"]))
sims = cosine_similarity(list(hinos_analise["word_embedding"]))

# hinos mais semelhantes ao hino 443
similarities_tfidf = list(enumerate(sims_tfidf[443]))
similarities_tfidf = sorted(similarities_tfidf, key=lambda x: x[1], reverse=True)

similarities_lp = list(enumerate(sims_lp[443]))
similarities_lp = sorted(similarities_lp, key=lambda x: x[1], reverse=True)

similarities = list(enumerate(sims[443]))
similarities = sorted(similarities, key=lambda x: x[1], reverse=True)

print("Mais parecidos com o hino 443: " + hinos_analise["nome"].iloc[443])
print("TF-IDF:")
for idx, score in similarities_tfidf[1:6]:
    print(f"Hino {idx}: {hinos_analise['nome'].iloc[idx]} → similaridade {score:.3f}")

print("Length Penalty:")
for idx, score in similarities_lp[1:6]:
    print(f"Hino {idx}: {hinos_analise['nome'].iloc[idx]} → similaridade {score:.3f}")

print("Uniform:")
for idx, score in similarities[1:6]:
    print(f"Hino {idx}: {hinos_analise['nome'].iloc[idx]} → similaridade {score:.3f}")
# Out:
# Mais parecidos com o hino 443: HÁ UM RIO DE ÁGUAS VIVAS
# TF-IDF:
# Hino 435: FLUIRÁ COMO UM RIO → similaridade 0.753
# Hino 310: MESTRE O MAR SE REVOLTA → similaridade 0.752
# Hino 552: PÁTRIA MINHA → similaridade 0.747
# Hino 544: EM BREVE O DIA CHEGARÁ → similaridade 0.745
# Hino 687: QUEM É COMO TU? → similaridade 0.741
# Length Penalty:
# Hino 310: MESTRE O MAR SE REVOLTA → similaridade 0.888
# Hino 552: PÁTRIA MINHA → similaridade 0.874
# Hino 388: SÓ TU ÉS, SENHOR → similaridade 0.870
# Hino 539: JUNTO AO TRONO DE DEUS, PREPARADO → similaridade 0.869
# Hino 307: PELO VALE ESCURO SEGUIREI JESUS → similaridade 0.866
# Uniform:
# Hino 310: MESTRE O MAR SE REVOLTA → similaridade 0.888
# Hino 552: PÁTRIA MINHA → similaridade 0.874
# Hino 388: SÓ TU ÉS, SENHOR → similaridade 0.870
# Hino 539: JUNTO AO TRONO DE DEUS, PREPARADO → similaridade 0.869
# Hino 307: PELO VALE ESCURO SEGUIREI JESUS → similaridade 0.866

# %% [markdown]
# ---
#
# **A seguir:** Criação de DataFrames de similaridade para visualização e análise dos resultados dos diferentes métodos de embeddings.

# %%
sims_tfidf_df = pd.DataFrame(
    sims_tfidf, index=hinos_analise.index, columns=hinos_analise.index
)
sims_lp_df = pd.DataFrame(
    sims_lp, index=hinos_analise.index, columns=hinos_analise.index
)
sims_df = pd.DataFrame(sims, index=hinos_analise.index, columns=hinos_analise.index)

# %% [markdown]
# ---
#
# **A seguir:** Visualização das matrizes de similaridade entre hinos utilizando heatmaps para os diferentes métodos de embeddings.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(1, 3, figsize=(24, 5))

sns.heatmap(sims_tfidf_df, cmap="viridis", annot=False, ax=ax[0])
sns.heatmap(sims_lp_df, cmap="viridis", annot=False, ax=ax[1])
sns.heatmap(sims_df, cmap="viridis", annot=False, ax=ax[2])
plt.title("Similaridade entre hinos (Word Embeddings)")
plt.show()

# %% [markdown]
# ---
#
# **A seguir:** Identificação dos pares de hinos com alta similaridade, destacando possíveis relações temáticas ou estilísticas.

# %%
high_similarity_word2vec = sims_tfidf_df[
    (sims_tfidf_df > 0.5) & (sims_tfidf_df < 1.0)
].stack()  # .reset_index()
high_similarity_word2vec = high_similarity_word2vec[
    high_similarity_word2vec.index.get_level_values(0)
    < high_similarity_word2vec.index.get_level_values(1)
]
high_similarity_word2vec.sort_values(ascending=False).head(10)
# Out:
# numero  numero
# 106     179       0.996136
# 521     610       0.992104
# 651     655       0.991716
# 520     521       0.991697
# 437     547       0.991252
# 359     521       0.990224
# 636     663       0.990222
# 547     558       0.986115
# 359     610       0.985993
# 437     558       0.985179
# dtype: float64

# %% [markdown]
# ---
#
# **A seguir:** Redução de dimensionalidade dos embeddings dos hinos utilizando PCA, t-SNE e UMAP para visualização e agrupamento.

# %% [markdown]
# ## Clustering

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap


pca = PCA(n_components=2)
tsne = TSNE(
    n_components=2,  # 2D
    perplexity=30,  # balanceia "quantos vizinhos" considerar (20-50 costuma ser bom)
    # n_iter=1000,  # número de iterações
    random_state=42,
)
umap_model = umap.UMAP(
    n_neighbors=15,  # controla quão “local” é o agrupamento (10–50 bons valores)
    min_dist=0.1,  # densidade dos pontos no espaço 2D (0 = pontos bem juntos, 0.5 = mais espalhados)
    n_components=2,  # queremos 2D para visualização
    random_state=42,
)

X = np.vstack(hinos_analise["word_embedding_tfidf"].values)

X_pca = pca.fit_transform(X)
X_tsne = tsne.fit_transform(X)
X_umap = umap_model.fit_transform(X)

hinos_analise["word_pca1"] = X_pca[:, 0]
hinos_analise["word_pca2"] = X_pca[:, 1]

hinos_analise["word_tsne1"] = X_tsne[:, 0]
hinos_analise["word_tsne2"] = X_tsne[:, 1]

hinos_analise["word_umap1"] = X_umap[:, 0]
hinos_analise["word_umap2"] = X_umap[:, 1]
# Out:
# c:\Users\lucas\.conda\envs\hinos\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# ---
#
# **A seguir:** Visualização dos agrupamentos dos hinos por embeddings reduzidos, utilizando scatterplots para PCA, t-SNE e UMAP.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Criar figura com 3 subplots lado a lado
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot PCA
sns.scatterplot(
    data=hinos_analise,
    x="word_pca1",
    y="word_pca2",
    ax=axes[0],
)
axes[0].set_title("PCA - Hinos agrupados por embeddings")
axes[0].legend(bbox_to_anchor=(1.05, 1), loc="upper left")

# Plot t-SNE
sns.scatterplot(
    data=hinos_analise,
    x="word_tsne1",
    y="word_tsne2",
    ax=axes[1],
)
axes[1].set_title("t-SNE - Hinos agrupados por embeddings")
axes[1].legend(bbox_to_anchor=(1.05, 1), loc="upper left")

# Plot UMAP
sns.scatterplot(
    data=hinos_analise,
    x="word_umap1",
    y="word_umap2",
    ax=axes[2],
)
axes[2].set_title("UMAP - Hinos agrupados por embeddings")
axes[2].legend(bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_9440\3998726163.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# C:\Users\lucas\AppData\Local\Temp\ipykernel_9440\3998726163.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend(bbox_to_anchor=(1.05, 1), loc="upper left")
# C:\Users\lucas\AppData\Local\Temp\ipykernel_9440\3998726163.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[2].legend(bbox_to_anchor=(1.05, 1), loc="upper left")

# %% [markdown]
# ---
#
# **A seguir:** Análise de agrupamento dos hinos utilizando KMeans, avaliação do número ideal de clusters com o coeficiente de Silhouette.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

range_n_clusters = range(2, 12)
silhouette_scores = []

for k in range_n_clusters:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_umap)
    score = silhouette_score(X_umap, labels)
    silhouette_scores.append(score)
    print(f"k = {k}, silhouette = {score:.4f}")

# Visualiza o resultado
plt.figure(figsize=(8, 5))
plt.plot(range_n_clusters, silhouette_scores, marker="o")
plt.title("Análise de Silhouette para seleção de k")
plt.xlabel("Número de clusters (k)")
plt.ylabel("Coeficiente médio de Silhouette")
plt.grid(True)
plt.show()
# Out:
# k = 2, silhouette = 0.3898
# k = 3, silhouette = 0.4008
# k = 4, silhouette = 0.3717
# k = 5, silhouette = 0.3622
# k = 6, silhouette = 0.3481
# k = 7, silhouette = 0.3603
# k = 8, silhouette = 0.3542
# k = 9, silhouette = 0.3418
# k = 10, silhouette = 0.3354
# k = 11, silhouette = 0.3388

# %% [markdown]
# ---
#
# **A seguir:** Visualização dos coeficientes de Silhouette para diferentes valores de k, auxiliando na escolha do número de clusters ideal.

# %%
from sklearn.metrics import silhouette_samples
import numpy as np

k = 8  # exemplo, número escolhido
kmeans = KMeans(n_clusters=k, random_state=42)
labels = kmeans.fit_predict(X_umap)

silhouette_vals = silhouette_samples(X_umap, labels)
y_lower = 10

plt.figure(figsize=(8, 6))
for i in range(k):
    ith_vals = silhouette_vals[labels == i]
    ith_vals.sort()
    size_cluster_i = ith_vals.shape[0]
    y_upper = y_lower + size_cluster_i
    plt.fill_betweenx(np.arange(y_lower, y_upper), 0, ith_vals)
    y_lower = y_upper + 10

plt.axvline(x=np.mean(silhouette_vals), color="red", linestyle="--")
plt.title(f"Silhouette plot para k={k}")
plt.xlabel("Coeficiente de Silhouette")
plt.ylabel("Clusters")
plt.show()

# %% [markdown]
# ---
#
# **A seguir:** Visualização dos coeficientes de Silhouette por cluster, detalhando a qualidade dos agrupamentos formados.

# %%
from sklearn.cluster import KMeans

n_clusters = 8
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
hinos_analise["word_cluster"] = kmeans.fit_predict(X_umap)

# %% [markdown]
# ---
#
# **A seguir:** Atribuição dos clusters aos hinos e visualização dos agrupamentos por embeddings reduzidos.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Criar figura com 3 subplots lado a lado
plt.figure(figsize=(10, 6))

# Plot PCA
sns.scatterplot(
    data=hinos_analise,
    x="word_umap1",
    y="word_umap2",
    hue="word_cluster",
    palette="tab10",
    s=80,
)
plt.title("PCA - Hinos agrupados por embeddings")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# **A seguir:** Análise dos termos mais frequentes em cada cluster e visualização da distribuição dos hinos por cluster.

# %%
from collections import Counter

for c in sorted(hinos_analise["word_cluster"].unique()):
    cluster_tokens = hinos_analise.loc[
        hinos_analise["word_cluster"] == c, "tokens_no_stops"
    ].sum()
    top_terms = Counter(cluster_tokens).most_common(10)
    print(f"\nCluster {c}:")
    print([t for t, _ in top_terms])
    print(hinos_analise.loc[hinos_analise["word_cluster"] == c, "nome"][:3])
# Out:
# Cluster 0:
# ['jesus', 'senhor', 'amor', 'fé', 'deus', 'vida', 'cristo', 'sempre', 'tudo', 'paz']
# numero
# 34                            QUANDO BUSCAMOS
# 44              CONFORME A SUA INFINITA GRAÇA
# 49    NA HORA EM QUE EU QUISER FALAR COM DEUS
# Name: nome, dtype: object
#
# Cluster 1:
# ['jesus', 'senhor', 'sangue', 'deus', 'amor', 'vida', 'cristo', 'glória', 'louvor', 'sempre']
# numero
# 1                O SANGUE DE JESUS TEM PODER
# 2    O SANGUE DE JESUS TEM PODER PARA SALVAR
# 5                             CLAMANDO ESTOU
# Name: nome, dtype: object
#
# Cluster 2:
# ['deus', 'jesus', 'glória', 'senhor', 'santo', 'rei', 'aleluia', 'nome', 'cristo', 'amor']
# numero
# 26    SEJA SÓ O SENHOR LOUVADO AQUI
# 46           AO SENTIR O TEU PERDÃO
# 55           SENHOR, MEU DEUS E PAI
# Name: nome, dtype: object
#
# Cluster 3:
# ['jesus', 'senhor', 'deus', 'amor', 'vem', 'luz', 'dia', 'vida', 'sempre', 'céu']
# numero
# 0    AQUILO QUE FUI NÃO SOU MAIS
# 3                     CLAMO A TI
# 9          SENHOR, ME CHEGO A TI
# Name: nome, dtype: object
#
# Cluster 4:
# ['amor', 'jesus', 'vida', 'cruz', 'paz', 'senhor', 'deus', 'cristo', 'salvador', 'sangue']
# numero
# 36          CRUCIFICADO FOI MEU JESUS
# 43                         VOU CLAMAR
# 54    HÁ VITÓRIA SEMPRE EM TI, SENHOR
# Name: nome, dtype: object
#
# Cluster 5:
# ['senhor', 'deus', 'jesus', 'glória', 'louvai', 'nome', 'sempre', 'rei', 'amor', 'grande']
# numero
# 10           VAMOS LAVAR AS VESTES
# 15              CLAMAREI, CLAMAREI
# 18    PROSTRADO ESTOU DIANTE DE TI
# Name: nome, dtype: object
#
# Cluster 6:
# ['jesus', 'senhor', 'deus', 'quero', 'cristo', 'céu', 'vai', 'amor', 'vou', 'sei']
# numero
# 4               QUANDO TE PROSTRARES
# 6                 JESUS, Ó MEU JESUS
# 20    O TEU PECADO TU QUERES DEIXAR?
# Name: nome, dtype: object
#
# Cluster 7:
# ['vem', 'jesus', 'senhor', 'voz', 'deus', 'cristo', 'coração', 'glória', 'luz', 'amor']
# numero
# 13    PÕE TEU SANGUE SOBRE MIM
# 16          SE ANDARMOS NA LUZ
# 24      EIS O CORDEIRO DE DEUS
# Name: nome, dtype: object

# %%
print(hinos_analise["word_cluster"].value_counts().sort_index())
# Out:
# word_cluster
# 0     87
# 1    125
# 2     98
# 3    131
# 4     69
# 5    112
# 6    100
# 7     73
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# **A seguir:** Extração de tópicos dos hinos utilizando LDA e NMF, atribuição dos tópicos aos hinos e visualização da distribuição dos tópicos.

# %% [markdown]
# ## Tópicos

# %% [markdown]
# ---
#
# **A seguir:** Visualização dos agrupamentos dos hinos por tópicos, utilizando scatterplots para PCA, t-SNE e UMAP.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF

n_topics = n_clusters

# Criar TF-IDF apenas para análise de tópicos
vectorizer = TfidfVectorizer(
    max_features=500,
    stop_words=None,  # você já removeu as stopwords
    ngram_range=(1, 3),  # uni, bi e trigramas
    min_df=2,  # palavra deve aparecer em pelo menos 2 documentos
)

# Usar texto já limpo (sem stopwords)
texts_for_topics = [" ".join(tokens) for tokens in hinos_analise["tokens_no_stops"]]
X_tfidf = vectorizer.fit_transform(texts_for_topics)

# Agora podemos usar LDA e NMF
lda = LatentDirichletAllocation(n_components=n_topics, random_state=42, max_iter=10)
lda_topics = lda.fit_transform(X_tfidf)

# NMF também funciona com TF-IDF
nmf = NMF(n_components=n_topics, random_state=42, max_iter=100)
nmf_topics = nmf.fit_transform(X_tfidf)


def display_topics(model, feature_names, n_top_words=10):
    for idx, topic in enumerate(model.components_):
        print(f"\nTópico {idx+1}:")
        top_words = [feature_names[i] for i in topic.argsort()[: -n_top_words - 1 : -1]]
        print(f"Palavras-chave: {' | '.join(top_words)}")


feature_names = vectorizer.get_feature_names_out()

print("=== LDA (Latent Dirichlet Allocation) ===")
display_topics(lda, feature_names)

print("\n=== NMF (Non-negative Matrix Factorization) ===")
display_topics(nmf, feature_names)

# Atribuir tópicos aos hinos
hinos_analise["LDA_topic"] = lda_topics.argmax(axis=1)
hinos_analise["NMF_topic"] = nmf_topics.argmax(axis=1)
# Out:
# === LDA (Latent Dirichlet Allocation) ===
#
# Tópico 1:
# Palavras-chave: senhor | deus | fé | amor | pai | louvai | cada | nome | jesus | louvor
#
# Tópico 2:
# Palavras-chave: jesus | amor | cristo | vida | deus | senhor | cruz | paz | sempre | coração
#
# Tópico 3:
# Palavras-chave: vem | quero | senhor | obra | voz | povo | somente | espírito | sofreu | libertação
#
# Tópico 4:
# Palavras-chave: glória | senhor | jesus | vem | rei | deus | igreja | jerusalém | breve | glória glória
#
# Tópico 5:
# Palavras-chave: santo | santo santo | deus | hosana | santo santo santo | amor | senhor | amor amor | força | feliz jesus
#
# Tópico 6:
# Palavras-chave: sangue | sangue jesus | comunhão | senhor | purificar | jesus | dá | clamo | plena | hora
#
# Tópico 7:
# Palavras-chave: vencedor | louvarei | senhor | tens | feito | maravilhas | vidas | tribulação | grandes | faz
#
# Tópico 8:
# Palavras-chave: abre | dai | venho | porta | nunca | deixa | glória deus | emanuel | brilhar | estrela
#
# === NMF (Non-negative Matrix Factorization) ===
#
# Tópico 1:
# Palavras-chave: jesus | cristo | vida | céu | paz | luz | mundo | feliz | dia | vai
#
# Tópico 2:
# Palavras-chave: senhor | quero | senhor senhor | voz | louvor | coração | alma | sei | salvação | cantarei
#
# Tópico 3:
# Palavras-chave: vem | vem vem | amado | maranata | vem jesus | igreja | espírito | voz | vem senhor | jesus vem
#
# Tópico 4:
# Palavras-chave: glória | rei | santo | glória glória | santo santo | nome | louvor | jesus | jerusalém | glória glória glória
#
# Tópico 5:
# Palavras-chave: sangue | sangue jesus | comunhão | jesus | libertação | cruz | purificar | dá | perdão | vitória
#
# Tópico 6:
# Palavras-chave: deus | espírito | tudo | senhor deus | glória deus | israel | deus deus | céus | temas | mão
#
# Tópico 7:
# Palavras-chave: amor | grande | grande amor | cruz | amor deus | amor amor | tudo | tão | todo | vida
#
# Tópico 8:
# Palavras-chave: aleluia | aleluia aleluia | vou | amém | cantar | todos | glória | salva | vitória | amado

# %%
print(f"\nDistribuição LDA:")
print(hinos_analise["LDA_topic"].value_counts().sort_index())

print(f"\nDistribuição NMF:")
print(hinos_analise["NMF_topic"].value_counts().sort_index())
# Out:
# Distribuição LDA:
# LDA_topic
# 0     91
# 1    443
# 2     32
# 3    150
# 4     25
# 5     37
# 6     13
# 7      4
# Name: count, dtype: int64
#
# Distribuição NMF:
# NMF_topic
# 0    154
# 1    151
# 2     83
# 3    100
# 4     63
# 5    107
# 6    103
# 7     34
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# **A seguir:** Visualização da distribuição dos tópicos atribuídos aos hinos por LDA e NMF.

# %%
# Visualizar a distribuição de tópicos
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# LDA
hinos_analise["LDA_topic"].value_counts().sort_index().plot(
    kind="bar", ax=axes[0], title="LDA (TF-IDF)"
)
axes[0].set_xlabel("Tópico")
axes[0].set_ylabel("Número de Hinos")

# NMF
hinos_analise["NMF_topic"].value_counts().sort_index().plot(
    kind="bar", ax=axes[1], title="NMF (TF-IDF)"
)
axes[1].set_xlabel("Tópico")
axes[1].set_ylabel("Número de Hinos")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# **A seguir:** Visualização dos agrupamentos dos hinos por tópicos em diferentes projeções (PCA, t-SNE, UMAP).

# %%
# Criar figura com 3 subplots lado a lado
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot PCA
sns.scatterplot(
    data=hinos_analise,
    x="word_pca1",
    y="word_pca2",
    hue="NMF_topic",
    palette="tab10",
    s=80,
    ax=axes[0],
)
axes[0].set_title("PCA - Hinos agrupados por tópicos")
axes[0].legend(bbox_to_anchor=(1.05, 1), loc="upper left")

# Plot t-SNE
sns.scatterplot(
    data=hinos_analise,
    x="word_tsne1",
    y="word_tsne2",
    hue="NMF_topic",
    palette="tab10",
    s=80,
    ax=axes[1],
)
axes[1].set_title("t-SNE - Hinos agrupados por tópicos")
axes[1].legend(bbox_to_anchor=(1.05, 1), loc="upper left")

# Plot UMAP
sns.scatterplot(
    data=hinos_analise,
    x="word_umap1",
    y="word_umap2",
    hue="NMF_topic",
    palette="tab10",
    s=80,
    ax=axes[2],
)
axes[2].set_title("UMAP - Hinos agrupados por tópicos")
axes[2].legend(bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# **A seguir:** Salvamento dos resultados e informações enriquecidas dos hinos para uso em análises futuras.

# %% [markdown]
# ## Salvamento de informações novas

# %% [markdown]
# ---
#
# **Fim do notebook:** Finalização do processamento, com os dados prontos para exportação e uso em outras análises ou aplicações.

# %%
hinos_analise[
    [
        "nome",
        "texto_limpo",
        "texto_unico",
        "categoria_id",
        "categoria_abr",
        "num_tokens",
        "tokens_no_stops",
        "word_embedding_tfidf",
        "word_tsne1",
        "word_tsne2",
        "word_umap1",
        "word_umap2",
        "word_cluster",
        "NMF_topic",
    ]
].to_pickle("..\\assets\\hinos_analise_word_embeddings.pkl")

# %%
sims_tfidf_df.to_pickle("..\\assets\\similarity_matrix_word_embeddings.pkl")
